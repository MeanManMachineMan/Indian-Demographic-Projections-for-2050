# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
#Simple Linear Regression model for Population prediction
#First read the dataset as a Pandas Dataframe
indiadf = pd.read_csv("Data/population.csv", encoding = "latin-1")

#Set the index as the column['States/UT']
indiadf = indiadf.set_index('State/UT' )

#Take the transpose
indiadfT = indiadf.T

#Create a new column 'Years' which is now equal to the years we have the data of
indiadfT['Year'] = indiadfT.index

#Select all the columns from the dataframe
col = list(indiadfT.columns)

#Set the variable 'model' as an object of LinearRegression from sklearn
model = LinearRegression()
for i in range(0,34):    #34 since this table has 34 columns
    
    #Fit the model with one parameter as the 'years' column and the other as the state we want in an incremental fashion
    model.fit(indiadfT[['Year']], indiadfT.iloc[:,i])
    
    #Create a new column to story the predicted values for data plotting at a later stage
    indiadfT['Predicted_{}'.format(col[i])] = model.predict(indiadfT[['Year']])
    
    #Predict 2020 values(You can predict any year you wish to simply by replacing the year with a year of your choice)
    pred_2020 = model.predict([[2020]])
    pred_2020 = int(pred_2020)
    
    #Predict 2050 values
    pred_2050 = model.predict([[2050]])
    pred_2050 = int(pred_2050)
    
    #Calculate growth percentage from 2020-2050
    growth = (pred_2050 - pred_2020)/pred_2020
    
    #Print the output statewise
    print("The expected population of {} in 2050 is {} with a change of {:.3f}%.".format(col[i], pred_2050,growth))

#Comments remain the same for all the models below since it's the same pattern but different datasets.
# Out:
# The expected population of Andaman and Nicobar Islands in 2050 is 646 with a change of 0.426%.
# The expected population of Andhra Pradesh in 2050 is 120943 with a change of 0.305%.
# The expected population of Arunachal Pradesh in 2050 is 1996 with a change of 0.382%.
# The expected population of Assam in 2050 is 45680 with a change of 0.343%.
# The expected population of Bihar in 2050 is 143282 with a change of 0.346%.
# The expected population of Chandigarh in 2050 is 1735 with a change of 0.452%.
# The expected population of Chhattisgarh in 2050 is 35780 with a change of 0.334%.
# The expected population of Delhi in 2050 is 25778 with a change of 0.434%.
# The expected population of Goa in 2050 is 2128 with a change of 0.304%.
# The expected population of Gujarat in 2050 is 86793 with a change of 0.344%.
# The expected population of Haryana in 2050 is 36980 with a change of 0.366%.
# The expected population of Himachal Pradesh in 2050 is 9778 with a change of 0.312%.
# The expected population of Jammu and Kashmir in 2050 is 17752 with a change of 0.364%.
# The expected population of Jharkhand in 2050 is 45930 with a change of 0.338%.
# The expected population of Karnataka in 2050 is 87444 with a change of 0.323%.
# The expected population of Kerala in 2050 is 48466 with a change of 0.274%.
# The expected population of Lakshadweep in 2050 is 96 with a change of 0.315%.
# The expected population of Madhya Pradesh in 2050 is 104452 with a change of 0.354%.
# The expected population of Maharashtra in 2050 is 162262 with a change of 0.340%.
# The expected population of Manipur in 2050 is 4166 with a change of 0.376%.
# The expected population of Meghalaya in 2050 is 4237 with a change of 0.382%.
# The expected population of Mizoram in 2050 is 1627 with a change of 0.395%.
# The expected population of Nagaland in 2050 is 3282 with a change of 0.431%.
# The expected population of Odisha in 2050 is 59366 with a change of 0.307%.
# The expected population of Puducherry in 2050 is 1753 with a change of 0.361%.
# The expected population of Punjab in 2050 is 39487 with a change of 0.318%.
# The expected population of Rajasthan in 2050 is 99168 with a change of 0.367%.
# The expected population of Sikkim in 2050 is 925 with a change of 0.379%.
# The expected population of Tamil Nadu in 2050 is 97955 with a change of 0.277%.
# The expected population of Tripura in 2050 is 5699 with a change of 0.372%.
# The expected population of Uttar Pradesh in 2050 is 279162 with a change of 0.339%.
# The expected population of Uttarakhand in 2050 is 14370 with a change of 0.336%.
# The expected population of West Bengal in 2050 is 133286 with a change of 0.331%.
# The expected population of ALL INDIA in 2050 is 1722797862 with a change of 0.334%.

# %%
#Line plot for 3 cities' population
plt.plot(
    indiadfT['Year'], indiadfT.iloc[0:, 5], 'b-x',
    indiadfT['Year'], indiadfT.iloc[0:, 7], 'r-x',
    indiadfT['Year'], indiadfT.iloc[0:, 10], 'g-x',
    indiadfT['Year'], indiadfT['Predicted_Chandigarh'], 'y-',
    indiadfT['Year'], indiadfT['Predicted_Delhi'], 'y-',
    indiadfT['Year'], indiadfT['Predicted_Haryana'], 'y-'
)
plt.grid(True)
plt.xlabel('Year')
plt.ylabel('Population Estimates in 2050')
plt.legend([indiadfT.columns[5],indiadfT.columns[7],indiadfT.columns[10], 'Best Fit Line'])
plt.show()

# %%
#Simple Linear Regression model for Sex Ratio prediction
indiadf = pd.read_csv("Data/sex_ratio.csv", encoding = "latin-1")
indiadf = indiadf.set_index('State/UT' )
indiadfT = indiadf.T
indiadfT['Year'] = indiadfT.index
col = list(indiadfT.columns)
model = LinearRegression()
for i in range(0,34):
    model.fit(indiadfT[['Year']], indiadfT.iloc[:,i])
    indiadfT['Predicted_{}'.format(col[i])] = model.predict(indiadfT[['Year']])
    pred_2020 = model.predict([[2020]])
    pred_2020 = int(pred_2020)
    pred_2050 = model.predict([[2050]])
    pred_2050 = int(pred_2050)
    growth = (pred_2050 - pred_2020)/pred_2020
    print("The expected sex-ratio of {} in 2050 is {} with a change of {:.3f}%.".format(col[i], pred_2050,growth))
# Out:
# The expected sex-ratio of Andaman & Nicobar Islands in 2050 is 899 with a change of 0.045%.
# The expected sex-ratio of Andhra Pradesh in 2050 is 865 with a change of -0.063%.
# The expected sex-ratio of Arunachal Pradesh in 2050 is 989 with a change of 0.068%.
# The expected sex-ratio of Assam in 2050 is 1003 with a change of 0.044%.
# The expected sex-ratio of Bihar in 2050 is 947 with a change of 0.020%.
# The expected sex-ratio of Chandigarh in 2050 is 748 with a change of -0.025%.
# The expected sex-ratio of Chhatisgarh in 2050 is 972 with a change of -0.008%.
# The expected sex-ratio of Delhi in 2050 is 727 with a change of -0.068%.
# The expected sex-ratio of Goa in 2050 is 925 with a change of -0.022%.
# The expected sex-ratio of Gujarat in 2050 is 654 with a change of -0.185%.
# The expected sex-ratio of Haryana in 2050 is 885 with a change of 0.014%.
# The expected sex-ratio of Himachal Pradesh in 2050 is 751 with a change of -0.138%.
# The expected sex-ratio of Jammu & Kashmir in 2050 is 647 with a change of -0.181%.
# The expected sex-ratio of Jharkhand in 2050 is 972 with a change of 0.025%.
# The expected sex-ratio of Karnataka in 2050 is 816 with a change of -0.087%.
# The expected sex-ratio of Kerala in 2050 is 1110 with a change of 0.034%.
# The expected sex-ratio of Lakshadweep in 2050 is 958 with a change of 0.008%.
# The expected sex-ratio of Madhya Pradesh in 2050 is 914 with a change of 0.000%.
# The expected sex-ratio of Maharashtra in 2050 is 888 with a change of -0.024%.
# The expected sex-ratio of Manipur in 2050 is 1092 with a change of 0.067%.
# The expected sex-ratio of Meghalaya in 2050 is 997 with a change of 0.019%.
# The expected sex-ratio of Mizoram in 2050 is 1012 with a change of 0.048%.
# The expected sex-ratio of Nagaland in 2050 is 963 with a change of 0.041%.
# The expected sex-ratio of Orissa in 2050 is 879 with a change of -0.053%.
# The expected sex-ratio of Pondicherry in 2050 is 1016 with a change of 0.016%.
# The expected sex-ratio of Punjab in 2050 is 717 with a change of -0.108%.
# The expected sex-ratio of Rajasthan in 2050 is 877 with a change of -0.022%.
# The expected sex-ratio of Sikkim in 2050 is 782 with a change of -0.061%.
# The expected sex-ratio of Tamil Nadu in 2050 is 930 with a change of -0.027%.
# The expected sex-ratio of Tripura in 2050 is 963 with a change of 0.009%.
# The expected sex-ratio of Uttar Pradesh in 2050 is 916 with a change of 0.020%.
# The expected sex-ratio of Uttaranchal in 2050 is 808 with a change of -0.084%.
# The expected sex-ratio of West Bengal in 2050 is 677 with a change of -0.163%.
# The expected sex-ratio of India in 2050 is 965 with a change of 0.021%.

# %%
#Bar plot for sex ratios in 2001 and 2011 for Andaman-Lakshadweep
indiadf.iloc[:17, :].plot.bar(y = {'2001', '2011'}, rot = 90)

# %%
#Bar plot for sex ratios in 2001 and 2011 for remaining states
indiadf.iloc[17:, :].plot.bar(y = {'2001', '2011'}, rot = 90)

# %%
#Simple Linear Regression model for Life Expectancy prediction
indiadf = pd.read_csv("Data/expectancy.csv", encoding = "latin-1")
indiadf = indiadf.set_index('State/UT' )
indiadfT = indiadf.T
indiadfT['Year'] = indiadfT.index
col = list(indiadfT.columns)
model = LinearRegression()
for i in range(0,22):
    model.fit(indiadfT[['Year']], indiadfT.iloc[:,i])
    indiadfT['Predicted_{}'.format(col[i])] = model.predict(indiadfT[['Year']])
    pred_2020 = model.predict([[2020]])
    pred_2020 = int(pred_2020)
    pred_2050 = model.predict([[2050]])
    pred_2050 = int(pred_2050)
    growth = (pred_2050 - pred_2020)/pred_2020
    print("The life expectancy of {} in 2050 is {} with a change of {:.3f}%.".format(col[i], pred_2050,growth))
# Out:
# The life expectancy of Andhra Pradesh in 2050 is 73 with a change of 0.090%.
# The life expectancy of Assam in 2050 is 76 with a change of 0.152%.
# The life expectancy of Bihar in 2050 is 86 with a change of 0.194%.
# The life expectancy of Chhattisgarh in 2050 is 74 with a change of 0.121%.
# The life expectancy of Delhi in 2050 is 86 with a change of 0.147%.
# The life expectancy of Gujarat in 2050 is 77 with a change of 0.116%.
# The life expectancy of Haryana in 2050 is 71 with a change of 0.060%.
# The life expectancy of Himachal Pradesh in 2050 is 78 with a change of 0.099%.
# The life expectancy of Jammu and Kashmir in 2050 is 89 with a change of 0.187%.
# The life expectancy of Jharkhand in 2050 is 65 with a change of 0.000%.
# The life expectancy of Karnataka in 2050 is 74 with a change of 0.088%.
# The life expectancy of Kerala in 2050 is 68 with a change of -0.029%.
# The life expectancy of Madhya Pradesh in 2050 is 79 with a change of 0.197%.
# The life expectancy of Maharashtra in 2050 is 79 with a change of 0.113%.
# The life expectancy of Odisha in 2050 is 81 with a change of 0.191%.
# The life expectancy of Punjab in 2050 is 72 with a change of 0.043%.
# The life expectancy of Rajasthan in 2050 is 80 with a change of 0.159%.
# The life expectancy of Tamil Nadu in 2050 is 79 with a change of 0.113%.
# The life expectancy of Uttar Pradesh in 2050 is 76 with a change of 0.152%.
# The life expectancy of Uttrakhand in 2050 is 74 with a change of 0.057%.
# The life expectancy of West Bengal in 2050 is 83 with a change of 0.153%.
# The life expectancy of ALL INDIA in 2050 is 77 with a change of 0.132%.

# %%
plt.plot(
    indiadfT['Year'], indiadfT.iloc[0:, 21], 'b-x',
    indiadfT['Year'], indiadfT['Predicted_ALL INDIA'], 'y-'
)
plt.grid(False)
plt.xlabel('Year')
plt.ylabel('Life Expectancy Estimates in 2050')
plt.legend([indiadfT.columns[21], 'Best Fit Line'])
plt.show()

# %%
#Simple Linear Regression model for Population Distribution prediction
indiadf = pd.read_csv("Data/pop_dist.csv", encoding = "latin-1")
indiadf = indiadf.set_index('State/UT' )
indiadfT = indiadf.T
indiadfT['Year'] = indiadfT.index
col = list(indiadfT.columns)
model = LinearRegression()
for i in range(0,23):
    model.fit(indiadfT[['Year']], indiadfT.iloc[:,i])
    indiadfT['Predicted_{}'.format(col[i])] = model.predict(indiadfT[['Year']])
    pred_2020 = model.predict([[2020.4]])
    pred_2020 = int(pred_2020)
    pred_2050 = model.predict([[2050.4]])
    pred_2050 = int(pred_2050)
    growth = (pred_2050 - pred_2020)/pred_2020
    print("The estimated age distribution in the bracket 20-24 of {} in 2050 is {} with a change of {:.3f}%.".format(col[i], pred_2050,growth))
# Out:
# The estimated age distribution in the bracket 20-24 of India in 2050 is 128213 with a change of 0.293%.
# The estimated age distribution in the bracket 20-24 of Jammu and Kashmir in 2050 is 1251 with a change of 0.282%.
# The estimated age distribution in the bracket 20-24 of Himachal Pradesh in 2050 is 667 with a change of 0.228%.
# The estimated age distribution in the bracket 20-24 of Punjab in 2050 is 2904 with a change of 0.281%.
# The estimated age distribution in the bracket 20-24 of Uttaranchal in 2050 is 1076 with a change of 0.306%.
# The estimated age distribution in the bracket 20-24 of Haryana in 2050 is 3059 with a change of 0.390%.
# The estimated age distribution in the bracket 20-24 of Delhi in 2050 is 2751 with a change of 0.584%.
# The estimated age distribution in the bracket 20-24 of Rajasthan in 2050 is 7737 with a change of 0.343%.
# The estimated age distribution in the bracket 20-24 of Uttar Pradesh in 2050 is 23042 with a change of 0.350%.
# The estimated age distribution in the bracket 20-24 of Bihar in 2050 is 10429 with a change of 0.282%.
# The estimated age distribution in the bracket 20-24 of Assam in 2050 is 3264 with a change of 0.270%.
# The estimated age distribution in the bracket 20-24 of West Bengal in 2050 is 8880 with a change of 0.218%.
# The estimated age distribution in the bracket 20-24 of Jharkhand in 2050 is 3345 with a change of 0.274%.
# The estimated age distribution in the bracket 20-24 of Orissa in 2050 is 3955 with a change of 0.206%.
# The estimated age distribution in the bracket 20-24 of Chhatisgarh in 2050 is 2606 with a change of 0.291%.
# The estimated age distribution in the bracket 20-24 of Madhya Pradesh in 2050 is 8348 with a change of 0.353%.
# The estimated age distribution in the bracket 20-24 of Gujarat in 2050 is 6505 with a change of 0.313%.
# The estimated age distribution in the bracket 20-24 of Maharashtra in 2050 is 12617 with a change of 0.335%.
# The estimated age distribution in the bracket 20-24 of Andhra Pradesh in 2050 is 8259 with a change of 0.209%.
# The estimated age distribution in the bracket 20-24 of Karnataka in 2050 is 5947 with a change of 0.234%.
# The estimated age distribution in the bracket 20-24 of Kerala in 2050 is 3149 with a change of 0.178%.
# The estimated age distribution in the bracket 20-24 of Tamil Nadu in 2050 is 6042 with a change of 0.153%.
# The estimated age distribution in the bracket 20-24 of NE States in 2050 is 1403 with a change of 0.233%.

# %%
#Horizontal bar plot for 2001,2006 and 2011 in the age group of 20-24 for half the states
indiadf.iloc[1:12,:].plot.barh(y = {'2001.4', '2006.4', '2011.4'}, rot = 0)

# %%
#Horizontal bar plot for 2001,2006 and 2011 in the age group of 20-24 for other half of the states
indiadf.iloc[12:,:].plot.barh(y = {'2001.4', '2006.4', '2011.4'}, rot = 0)
